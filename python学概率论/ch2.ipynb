# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %% [markdown]
# ## 实验1

# %%
n = 20
p = 0.2
x = np.arange(0, 21, 1)  # [0 1 2 3 4 .. 20] 分成21个点
y_pmf = stats.binom.pmf(x, n, p)
y_cdf = stats.binom.cdf(x, n, p)

# %%
print(y_pmf)
# Out:
# [1.15292150e-02 5.76460752e-02 1.36909429e-01 2.05364143e-01
#  2.18199402e-01 1.74559522e-01 1.09099701e-01 5.45498505e-02
#  2.21608768e-02 7.38695892e-03 2.03141370e-03 4.61684933e-04
#  8.65659248e-05 1.33178346e-05 1.66472932e-06 1.66472932e-07
#  1.30056978e-08 7.65041050e-10 3.18767104e-11 8.38860800e-13
#  1.04857600e-14]

# %%
plt.bar(x, y_pmf)
plt.plot(x, y_cdf)
plt.title("Binomial distribution: n=%i, p=%.2f" % (n, p))
plt.xlabel("n")
plt.ylabel("probalility")
plt.text(x=4.5, y=0.25, s="pmf", alpha=0.75, weight="bold", color="blue")
plt.text(x=14.5, y=0.9, s="cdf", rotation=.75, weight="bold", color="red")
plt.show()

# %% [markdown]
# ## 实验2

# %%
n = 20
p = 0.2
x = np.arange(0, 11, 1)
y_pmf = stats.binom.pmf(x, n, p)

# %%
plt.plot(x, y_pmf, "o-")

# %% [markdown]
# ## 实验3

# %%
n = 10
x = np.arange(0, 11, 1)
plt.plot(x, stats.binom.pmf(x, n, 0.25), "o-", color="blue")
plt.plot(x, stats.binom.pmf(x, n, 0.5), "o-", color="red")
plt.plot(x, stats.binom.pmf(x, n, 0.75), "o-", color="green")

# %% [markdown]
# ## 实验4

# %%
n = 20
x = np.arange(0, 21, 1)
plt.plot(x, stats.poisson.pmf(x, 1), "o-", color="blue")
plt.plot(x, stats.poisson.pmf(x, 2), "o-", color="red")
plt.plot(x, stats.poisson.pmf(x, 3), "o-", color="green")
plt.plot(x, stats.poisson.pmf(x, 4), "o-", color="cyan")

# %%
n = 20
x = np.arange(-21, 21, 1)
plt.plot(x, stats.norm.pdf(x, -2, 1), "o-", color="blue")

# %%
sigma = 1
x = np.linspace(-6, 6, 1000)
plt.plot(x, stats.norm.pdf(x, -2, sigma), '-')
plt.plot(x, stats.norm.pdf(x, 0, sigma), '-')
plt.plot(x, stats.norm.pdf(x, 2, sigma), '-')

# %%
mu = 0
x = np.linspace(-6, 6, 1000)
plt.plot(x, stats.norm.pdf(x, mu, 0.5), '-')
plt.plot(x, stats.norm.pdf(x, mu, 1), '-')
plt.plot(x, stats.norm.pdf(x, mu, 1.5), '-')

# %%
import math

# %%
alpha = math.comb(20, 4) * ((0.8) ** 4) * ((0.2) ** 16)

# %%
alpha
# Out:
# 1.3005697843200014e-08

# %%
(0.8) ** 4
# Out:
# 0.4096000000000001

# %%
math.comb(19, 3) / math.comb(20, 4)
# Out:
# 0.2

# %%
math.comb(18, 2) / math.comb(20, 4) + math.comb(19, 3) * math.comb(2, 1) / math.comb(20, 4)
# Out:
# 0.43157894736842106

# %%
1 - 0.020 - 0.043
# Out:
# 0.9369999999999999

# %%
0.1 * math.comb(19, 4) / math.comb(20, 4) + 0.1 * math.comb(18, 4) / math.comb(20, 4) + 0.8
# Out:
# 0.9431578947368422

# %%
0.8 / 0.943
# Out:
# 0.8483563096500532

# %%
1 / 3 * (1 / 10 * 7 / 3 + 7 / 15 * 8 / 14 + 5 / 25 * 20 / 24)
# Out:
# 0.2222222222222222

# %%
1 / 3 * (7 / 10 * 6 / 9 + 8 / 15 * 7 / 14 + 20 / 25 * 19 / 24)
# Out:
# 0.45555555555555555

# %%
0.222 / (0.222 + 0.455)
# Out:
# 0.327917282127031

# %%
20 / 61
# Out:
# 0.32786885245901637

# %%
(0.4 * 0.5 * 0.3 + 0.6 * 0.5 * 0.3 + 0.6 * 0.5 * 0.7) * 0.2
# Out:
# 0.072

# %%
(0.4 * 0.5 * 0.3 + 0.4 * 0.5 * 0.7 + 0.6 * 0.5 * 0.7) * 0.6
# Out:
# 0.24599999999999997

# %%
0.072 + 0.246 + 0.14
# Out:
# 0.458

# %%
(0.8) ** 3
# Out:
# 0.5120000000000001

# %%
math.comb(3, 2) * ((0.8) ** 2) * 0.9 * 0.2
# Out:
# 0.34560000000000013

# %%
math.comb(3, 1) * 0.8 * ((0.2) ** 2) * 0.5
# Out:
# 0.048000000000000015

# %%
((0.2) ** 3) * 0.2
# Out:
# 0.0016000000000000005

# %%
0.512 + 0.3456 + 0.048 + 0.0016
# Out:
# 0.9072000000000001

# %%
3 * (0.8) ** 2 * 0.2 * 0.1 / 0.098
# Out:
# 0.3918367346938777
